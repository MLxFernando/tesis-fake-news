# %%
import pandas as pd

# Ruta del archivo
file_path = "data/fake_new/raw/dataset.csv"  # Ajusta la ruta según la ubicación real

pd.set_option('display.max_colwidth', None)

# Cargar el archivo CSV
df = pd.read_csv(file_path)
print(df.loc[3])
# Muestra las primeras filas del dataset
print(df.head(2))
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...
